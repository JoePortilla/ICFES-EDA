# %% [markdown]
# # 0. Introducción
#
# <!-- <img src="https://raw.githubusercontent.com/JoePortilla/EnergyProductionCol-EDA/main/img/energyproduction_eda_cover.webp?token=GHSAT0AAAAAAB6AMADC5TFIULPHAY4XD3FUZBR77PA" width="800" alt="logo" style="display:block;margin:auto;"> -->
#
#
#
# ## Objetivo general
# Work in progress.
#
# ## Objetivo especifico
# Este notebook se centra en explorar y visualizar el conjunto de datos.
#
# ## Paquetes utilizados
# - Procesamiento de datos
#     - Pandas.
# - Procesamiento numérico.
#     - NumPy
# - Visualización de datos
#     - Seaborn
#     - Matplotlib.
#
# ## Dataset
#
# ## Referencias
#
# ## Instructor
# Joseph Santiago Portilla - Ingeniero Electrónico.
# - GitHub: https://github.com/JoePortilla
# - Twitter: https://twitter.com/JoePortilla
# - LinkedIn: https://www.linkedin.com/in/PortillaJoe
# - Kaggle: https://www.kaggle.com/joeportilla

# %% [markdown]
# # 1. Ajustes Iniciales

# %% [markdown]
# ## 1.1 Importación de Bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2. Definición de estilo de gráficas

# %%
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# # 2. Carga de Dataset y Revisión inicial

# %% [markdown]
# ## 2.1. Lectura de CSV

# %%
df0 = pd.read_csv('/kaggle/input/icfes-colombia-20182021/icfes_data.csv', sep='\t', low_memory=False)

# %% [markdown]
# ## 2.2. Exploración inicial del dataframe

# %% [markdown]
# ### Info. general del dataset

# %% [markdown]
# El conjunto de datos contiene las siguientes columnas:

# %%
df0.columns
# Out:
# Index(['ESTU_CONSECUTIVO', 'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD',
#        'ESTU_GENERO', 'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_ESTUDIANTE',
#        'ESTU_PAIS_RESIDE', 'ESTU_TIENEETNIA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA',
#        'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
# ...

# %%
df0.head()
# Out:
#    ESTU_CONSECUTIVO ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0  SB11202040001656                 TI          COLOMBIA           M
# 1  SB11202040001763                 TI          COLOMBIA           F
# 2  SB11202040001490                 TI          COLOMBIA           F
# 3  SB11202040096445                 TI          COLOMBIA           M
# 4  SB11202040048154                 TI          COLOMBIA           M
#
#   ESTU_FECHANACIMIENTO  PERIODO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  \
# 0           03/07/2003    20204      ESTUDIANTE         COLOMBIA
# 1           16/06/2003    20204      ESTUDIANTE         COLOMBIA
# 2           11/09/2003    20204      ESTUDIANTE         COLOMBIA
# 3           05/03/2004    20204      ESTUDIANTE         COLOMBIA
# 4           30/08/2003    20204      ESTUDIANTE         COLOMBIA
#
#   ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  ...  PUNT_GLOBAL PERCENTIL_GLOBAL  \
# 0              No            CALDAS  ...          261             61.0
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1650063 entries, 0 to 1650062
# Data columns (total 84 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   ESTU_CONSECUTIVO               1650063 non-null  object
#  1   ESTU_TIPODOCUMENTO             1650063 non-null  object
#  2   ESTU_NACIONALIDAD              1650063 non-null  object
#  3   ESTU_GENERO                    1649948 non-null  object
#  4   ESTU_FECHANACIMIENTO           1650063 non-null  object
#  5   PERIODO                        1650063 non-null  int64
#  6   ESTU_ESTUDIANTE                1650063 non-null  object
#  7   ESTU_PAIS_RESIDE               1650063 non-null  object
#  8   ESTU_TIENEETNIA                1645775 non-null  object
#  9   ESTU_DEPTO_RESIDE              1648767 non-null  object
#  10  ESTU_COD_RESIDE_DEPTO          1648767 non-null  float64
#  11  ESTU_MCPIO_RESIDE              1648767 non-null  object
# ...

# %% [markdown]
# ### Dimensión del datafrane

# %%
df0.shape
# Out:
# (1650063, 21)

# %% [markdown]
# # 3. Preprocesamiento

# %% [markdown]
# ## Feature selection

# %%
filt = ['ESTU_NACIONALIDAD', 'ESTU_GENERO', 'ESTU_PAIS_RESIDE', 'FAMI_ESTRATOVIVIENDA',
        'FAMI_TIENEINTERNET', 'FAMI_TIENECOMPUTADOR', 'ESTU_DEDICACIONLECTURADIARIA', 'COLE_NATURALEZA', 'COLE_BILINGUE',
       'COLE_DEPTO_UBICACION', 'COLE_MCPIO_UBICACION', 'PUNT_LECTURA_CRITICA', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
       'PUNT_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PUNT_GLOBAL', 'ESTU_ETNIA', 'ESTU_PILOPAGA', 'ESTU_LIMITA_MOTRIZ']
df = df0[filt]

# %%
df.sort_values('PUNT_GLOBAL', ascending=False, inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# ## Column renaming

# %% [markdown]
# ## Value renaming

# %% [markdown]
# ## Feature construction

# %% [markdown]
# ## Data filtering

# %% [markdown]
# ## 3.4. Dataframe preprocesado

# %%
df.head(3)
# Out:
#        ESTU_NACIONALIDAD ESTU_GENERO ESTU_PAIS_RESIDE ESTU_TIENEETNIA  \
# 264793          COLOMBIA           M         COLOMBIA              No
# 108755          COLOMBIA           M         COLOMBIA              No
# 95278           COLOMBIA           F         COLOMBIA              No
#
#        FAMI_ESTRATOVIVIENDA FAMI_TIENEINTERNET FAMI_TIENECOMPUTADOR  \
# 264793            Estrato 2                 No                   Si
# 108755            Estrato 1                 Si                   Si
# 95278             Estrato 2                 Si                   Si
#
#        ESTU_DEDICACIONLECTURADIARIA COLE_NATURALEZA COLE_BILINGUE  ...  \
# 264793        Entre 30 y 60 minutos         OFICIAL           NaN  ...
# 108755               Más de 2 horas         OFICIAL             N  ...
# 95278         Entre 30 y 60 minutos      NO OFICIAL           NaN  ...
#
#        COLE_MCPIO_UBICACION PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1650063 entries, 264793 to 299091
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   ESTU_NACIONALIDAD             1650063 non-null  object
#  1   ESTU_GENERO                   1649948 non-null  object
#  2   ESTU_PAIS_RESIDE              1650063 non-null  object
#  3   ESTU_TIENEETNIA               1645775 non-null  object
#  4   FAMI_ESTRATOVIVIENDA          1555890 non-null  object
#  5   FAMI_TIENEINTERNET            1566293 non-null  object
#  6   FAMI_TIENECOMPUTADOR          1590979 non-null  object
#  7   ESTU_DEDICACIONLECTURADIARIA  1563903 non-null  object
#  8   COLE_NATURALEZA               1650063 non-null  object
#  9   COLE_BILINGUE                 1388315 non-null  object
#  10  COLE_DEPTO_UBICACION          1650063 non-null  object
#  11  COLE_MCPIO_UBICACION          1650063 non-null  object
# ...

# %% [markdown]
# # X. Conclusiones EDA

# %% [markdown]
# - Work in progress
# -
